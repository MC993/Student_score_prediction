# %%
#libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_row', None)

# %%
data1 = pd.read_csv('train.csv')
data2 = pd.read_csv('test.csv')
data3 = pd.read_csv('Exam_Score_Prediction.csv')

train_df = data1.copy()
test_df = data2.copy()
previous_df = data3.copy()

print("First 5 rows of train data: \n", train_df.head())
print("First 5 rows of test data: \n", test_df.head())
# Out:
# First 5 rows of train data:
#     id  age  gender   course  study_hours  class_attendance internet_access  \
# 0   0   21  female     b.sc         7.91              98.8              no
# 1   1   18   other  diploma         4.95              94.8             yes
# 2   2   20  female     b.sc         4.68              92.6             yes
# 3   3   19    male     b.sc         2.00              49.5             yes
# 4   4   23    male      bca         7.65              86.9             yes
#
#    sleep_hours sleep_quality   study_method facility_rating exam_difficulty  \
# 0          4.9       average  online videos             low            easy
# 1          4.7          poor     self-study          medium        moderate
# 2          5.8          poor       coaching            high        moderate
# 3          8.3       average    group study            high        moderate
# 4          9.6          good     self-study            high            easy
#
#    exam_score
# 0        78.3
# 1        46.7
# 2        99.0
# 3        63.9
# 4       100.0
# First 5 rows of test data:
#         id  age  gender   course  study_hours  class_attendance  \
# 0  630000   24   other       ba         6.85              65.2
# 1  630001   18    male  diploma         6.61              45.0
# 2  630002   24  female   b.tech         6.60              98.5
# 3  630003   24    male  diploma         3.03              66.3
# 4  630004   20  female   b.tech         2.03              42.4
#
#   internet_access  sleep_hours sleep_quality study_method facility_rating  \
# 0             yes          5.2          poor  group study            high
# 1              no          9.3          poor     coaching             low
# 2             yes          6.2          good  group study          medium
# 3             yes          5.7       average        mixed          medium
# 4             yes          9.2       average     coaching             low
#
#   exam_difficulty
# 0            easy
# 1            easy
# 2        moderate
# 3        moderate
# 4        moderate

# %%
sleep_map = {
    "poor": 0,
    "average": 1,
    "good": 2

}

facility_map = {
    "low": 0,
    "medium": 1,
    "high": 2
}

difficulty_map = {
    "hard": 0,
    "moderate": 1,
    "easy": 2
}

method_map = {
    "self-study": 0,
    "online videos": 1,
    "group study": 2,
    "mixed": 3,
    "coaching": 4
}

train_df['sleep_quality'] = train_df['sleep_quality'].map(sleep_map)
test_df['sleep_quality'] = test_df['sleep_quality'].map(sleep_map)

train_df['facility_rating'] = train_df['facility_rating'].map(facility_map)
test_df['facility_rating'] = test_df['facility_rating'].map(facility_map)

train_df['exam_difficulty'] = train_df['exam_difficulty'].map(difficulty_map)
test_df['exam_difficulty'] = test_df['exam_difficulty'].map(difficulty_map)

train_df['study_method'] = train_df['study_method'].map(method_map)
test_df['study_method'] = test_df['study_method'].map(method_map)

# %%
#dropping course

train_df = train_df.drop(columns='course')
test_df = test_df.drop(columns='course')

# %%
gender_map = {
    "other": "female",
    "male": "male",
    "female": "female"
}

train_df['gender'] = train_df['gender'].map(gender_map)
test_df['gender'] = test_df['gender'].map(gender_map)

# %%
train_df_encoded = pd.get_dummies(train_df, columns=['gender', 'internet_access'], drop_first= True)
test_df_encoded = pd.get_dummies(test_df, columns=['gender', 'internet_access'], drop_first= True)

# %%
#train test split

from sklearn.model_selection import train_test_split

X = train_df_encoded.drop(columns='exam_score')
y = train_df_encoded['exam_score']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.3, random_state=42)

# %%
import optuna
from xgboost import XGBRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error, make_scorer

# %%
def objective(trial):
    """Optuna objective function for XGBRegressor hyperparameter optimization"""
    
    params = {
        # Core Parameters
        'n_estimators': trial.suggest_int('n_estimators', 100, 2000),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        
        # Tree Structure
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 20),
        'gamma': trial.suggest_float('gamma', 0, 5),
        'max_delta_step': trial.suggest_int('max_delta_step', 0, 10),
        'max_leaves': trial.suggest_int('max_leaves', 0, 256),
        
        # Regularization
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-8, 10.0, log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-8, 10.0, log=True),
        
        # Sampling
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'colsample_bylevel': trial.suggest_float('colsample_bylevel', 0.5, 1.0),
        'colsample_bynode': trial.suggest_float('colsample_bynode', 0.5, 1.0),
        
        # Learning Task
        'objective': 'reg:squarederror',
        
        # Fixed Parameters
        'random_state': 42,
        'n_jobs': -1,
        'verbosity': 0,
        'tree_method': 'hist',  # Faster than 'exact'
        'enable_categorical': False,
    }
    
    model = XGBRegressor(**params)
    
    # Use cross-validation
    cv_scores = cross_val_score(
        model, X, y, 
        cv=5, 
        scoring='neg_root_mean_squared_error',  # Or 'neg_mean_squared_error'
        n_jobs=-1
    )
    
    return np.mean(cv_scores)

# %%
study = optuna.create_study(direction='maximize')  # Maximize negative RMSE = minimize RMSE
study.optimize(objective, n_trials=50, timeout=3600)

print("Best trial:")
trial = study.best_trial
print(f"  Score (negative RMSE): {trial.value:.4f}")
print("  Best parameters:")
for key, value in trial.params.items():
    print(f"    {key}: {value}")
# Out:
# [I 2026-01-03 14:16:10,113] A new study created in memory with name: no-name-2b0e18e4-9eac-44d3-8dbf-81f3b7a9c4aa
# [I 2026-01-03 14:17:14,513] Trial 0 finished with value: -8.807148736627243 and parameters: {'n_estimators': 806, 'learning_rate': 0.05378555796180253, 'max_depth': 10, 'min_child_weight': 1, 'gamma': 1.8101326610040802, 'max_delta_step': 0, 'max_leaves': 54, 'reg_alpha': 0.056845572903750474, 'reg_lambda': 0.0016647735773694006, 'subsample': 0.6781034803607165, 'colsample_bytree': 0.927756707101791, 'colsample_bylevel': 0.775368821545652, 'colsample_bynode': 0.6264516818670206}. Best is trial 0 with value: -8.807148736627243.
# [I 2026-01-03 14:19:41,510] Trial 1 finished with value: -8.828349000890345 and parameters: {'n_estimators': 1438, 'learning_rate': 0.03278971117169096, 'max_depth': 8, 'min_child_weight': 10, 'gamma': 4.232675027553785, 'max_delta_step': 8, 'max_leaves': 225, 'reg_alpha': 0.0005100017914441204, 'reg_lambda': 0.0025094624972803632, 'subsample': 0.59962524994007, 'colsample_bytree': 0.7747600193792819, 'colsample_bylevel': 0.6314951996450291, 'colsample_bynode': 0.8632107717146114}. Best is trial 0 with value: -8.807148736627243.
# [I 2026-01-03 14:20:07,858] Trial 2 finished with value: -8.90258314041022 and parameters: {'n_estimators': 274, 'learning_rate': 0.01994981073079394, 'max_depth': 6, 'min_child_weight': 4, 'gamma': 3.160752585761697, 'max_delta_step': 7, 'max_leaves': 215, 'reg_alpha': 0.00018423890836748147, 'reg_lambda': 0.0073393178869217745, 'subsample': 0.7181286156270662, 'colsample_bytree': 0.7652382166343856, 'colsample_bylevel': 0.7779143874922094, 'colsample_bynode': 0.9042053217738575}. Best is trial 0 with value: -8.807148736627243.
. Best is trial 6 with value: -8.781953748012455.
# [I 2026-01-03 14:39:09,022] Trial 15 finished with value: -8.796935364059129 and parameters: {'n_estimators': 1681, 'learning_rate': 0.026697630313770117, 'max_depth': 7, 'min_child_weight': 7, 'gamma': 3.5366513805605386, 'max_delta_step': 3, 'max_leaves': 113, 'reg_alpha': 0.004211221318801897, 'reg_lambda': 5.0126583769540616e-05, 'subsample': 0.5101268012782803, 'colsample_bytree': 0.8219633937878397, 'colsample_bylevel': 0.8853345222453909, 'colsample_bynode': 0.9994572997522253}. Best is trial 6 with value: -8.781953748012455.
# [I 2026-01-03 14:42:16,291] Trial 16 finished with value: -8.793669409289418 and parameters: {'n_estimators': 1696, 'learning_rate': 0.021621724569453576, 'max_depth': 9, 'min_child_weight': 6, 'gamma': 3.8289181634605014, 'max_delta_step': 2, 'max_leaves': 256, 'reg_alpha': 0.00499082378885285, 'reg_lambda': 1.868180812128814e-05, 'subsample': 0.5087382713606026, 'colsample_bytree': 0.8350382797303338, 'colsample_bylevel': 0.8774779561728049, 'colsample_bynode': 0.9915795294887405}. Best is trial 6 with value: -8.781953748012455.
# [I 2026-01-03 14:44:20,736] Trial 17 finished with value: -8.801420093869469 and parameters: {'n_estimators': 1238, 'learning_rate': 0.01884443494142095, 'max_depth': 12, 'min_child_weight': 6, 'gamma': 4.210167447271306, 'max_delta_step': 2, 'max_leaves': 255, 'reg_alpha': 0.20993939068692782, 'reg_lambda': 7.256648514325181e-05, 'subsample': 0.580893959616088, 'colsample_bytree': 0.9939589603597507, 'colsample_bylevel': 0.9794254392531491, 'colsample_bynode': 0.5382143959126985}. Best is trial 6 with value: -8.781953748012455.
# [I 2026-01-03 14:47:08,758] Trial 18 finished with value: -8.792239025703028 and parameters: {'n_estimators': 1755, 'learning_rate': 0.018734669126318073, 'max_depth': 10, 'min_child_weight': 1, 'gamma': 3.9377297458260005, 'max_delta_step': 5, 'max_leaves': 254, 'reg_alpha': 0.037251792783960694, 'reg_lambda': 8.912163901957976, 'subsample': 0.6317115560308632, 'colsample_bytree': 0.8756911914852271, 'colsample_bylevel': 0.8609726557997797, 'colsample_bynode': 0.930754519128217}. Best is trial 6 with value: -8.781953748012455.
# [I 2026-01-03 14:49:19,328] Trial 19 finished with value: -8.817526559204982 and parameters: {'n_estimators': 1228, 'learning_rate': 0.03819246755306384, 'max_depth': 10, 'min_child_weight': 1, 'gamma': 4.895178475570017, 'max_delta_step': 6, 'max_leaves': 185, 'reg_alpha': 0.6100212554493835, 'reg_lambda': 4.32130719871375, 'subsample': 0.6573196885359942, 'colsample_bytree': 0.9156594881403985, 'colsample_bylevel': 0.9371251508035354, 'colsample_bynode': 0.9105059356509465}. Best is trial 6 with value: -8.781953748012455.
# [I 2026-01-03 14:52:29,953] Trial 20 finished with value: -8.790349381653181 and parameters: {'n_estimators': 1806, 'learning_rate': 0.015670255486239567, 'max_depth': 11, 'min_child_weight': 3, 'gamma': 0.797072065966473, 'max_delta_step': 5, 'max_leaves': 184, 'reg_alpha': 0.04258010315562357, 'reg_lambda': 0.13208069910822978, 'subsample': 0.6465572056701097, 'colsample_bytree': 0.9172010038494967, 'colsample_bylevel': 0.8523468606668642, 'colsample_bynode': 0.7713065780547663}. Best is trial 6 with value: -8.781953748012455.
# [I 2026-01-03 14:55:39,196] Trial 21 finished with value: -8.788303822175536 and parameters: {'n_estimators': 1797, 'learning_rate': 0.015678695578743025, 'max_depth': 11, 'min_child_weight': 3, 'gamma':
. Best is trial 6 with value: -8.781953748012455.
# [I 2026-01-03 15:13:48,152] Trial 27 finished with value: -8.79400063596297 and parameters: {'n_estimators': 1567, 'learning_rate': 0.024264806678798774, 'max_depth': 9, 'min_child_weight': 12, 'gamma': 1.3160456209675504, 'max_delta_step': 8, 'max_leaves': 118, 'reg_alpha': 0.5303955702599421, 'reg_lambda': 1.1729441617208147, 'subsample': 0.558610075840286, 'colsample_bytree': 0.7985214201872524, 'colsample_bylevel': 0.9259603747442142, 'colsample_bynode': 0.6863284842258148}. Best is trial 6 with value: -8.781953748012455.
# [I 2026-01-03 15:16:29,881] Trial 28 finished with value: -8.84316432269163 and parameters: {'n_estimators': 1885, 'learning_rate': 0.043725517566499617, 'max_depth': 8, 'min_child_weight': 8, 'gamma': 0.008813235418924537, 'max_delta_step': 7, 'max_leaves': 128, 'reg_alpha': 0.6935006852483333, 'reg_lambda': 0.2762697535508528, 'subsample': 0.7002742818926659, 'colsample_bytree': 0.72592228759219, 'colsample_bylevel': 0.8996929792931851, 'colsample_bynode': 0.7218064554653087}. Best is trial 6 with value: -8.781953748012455.
# Best trial:
#   Score (negative RMSE): -8.7820
#   Best parameters:
#     n_estimators: 1756
#     learning_rate: 0.01439127933032874
#     max_depth: 10
#     min_child_weight: 17
#     gamma: 0.5279028682843451
#     max_delta_step: 6
#     max_leaves: 144
#     reg_alpha: 0.09857545822388299
#     reg_lambda: 0.004254614173648278
#     subsample: 0.6559787280938627
#     colsample_bytree: 0.6637686843829025
#     colsample_bylevel: 0.9303164683921552
#     colsample_bynode: 0.7886793881524589

# %%
study.best_params
# Out:
# {'n_estimators': 1756,
#  'learning_rate': 0.01439127933032874,
#  'max_depth': 10,
#  'min_child_weight': 17,
#  'gamma': 0.5279028682843451,
#  'max_delta_step': 6,
#  'max_leaves': 144,
#  'reg_alpha': 0.09857545822388299,
#  'reg_lambda': 0.004254614173648278,
#  'subsample': 0.6559787280938627,
#  'colsample_bytree': 0.6637686843829025,
#  'colsample_bylevel': 0.9303164683921552,
#  'colsample_bynode': 0.7886793881524589}

# %%
xgb_params = {
    'n_estimators': 1756,
 'learning_rate': 0.01439127933032874,
 'max_depth': 10,
 'min_child_weight': 17,
 'gamma': 0.5279028682843451,
 'max_delta_step': 6,
 'max_leaves': 144,
 'reg_alpha': 0.09857545822388299,
 'reg_lambda': 0.004254614173648278,
 'subsample': 0.6559787280938627,
 'colsample_bytree': 0.6637686843829025,
 'colsample_bylevel': 0.9303164683921552,
 'colsample_bynode': 0.7886793881524589
}

xgb_model = XGBRegressor(**xgb_params)
cv_res = cross_val_score(xgb_model, X_train, y_train, cv=3, scoring='neg_log_loss')

print(f"Final CV scores: {cv_res}")
print(f"Mean CV score: {cv_res.mean():.4f} ± {cv_res.std():.4f}")

xgb_model.fit(X_train, y_train)
# Out:
# Final CV scores: [nan nan nan]
# Mean CV score: nan ± nan
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=0.9303164683921552,
#              colsample_bynode=0.7886793881524589,
#              colsample_bytree=0.6637686843829025, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, feature_weights=None,
#              gamma=0.5279028682843451, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01439127933032874,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=6, max_depth=10, max_leaves=144,
#              min_child_weight=17, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=1756, n_jobs=None,
#              num_parallel_tree=None, ...)
